# %%
#E:\Servicio\MEA2\20211004\H5\SPK
import h5py
import numpy as np
import matplotlib.pyplot as plt
path_fileh5 = "E:\\Servicio\\MEA2\\20211004\\H5\\SPK\\"

# %%
# Carga de los archivos

file_1 = h5py.File(path_fileh5+"CTR20211004s01A_SPK.h5", 'r')
file_2 = h5py.File(path_fileh5+"CTR20211004s01B_SPK.h5", 'r')
file_3 = h5py.File(path_fileh5+"CTR20211004s01C_SPK.h5", 'r')

# %%
keys_1 = list(file_1['Data']['Recording_0']['SegmentStream']['Stream_0'].keys())
keys_2 = list(file_2['Data']['Recording_0']['SegmentStream']['Stream_0'].keys())
keys_3 = list(file_3['Data']['Recording_0']['SegmentStream']['Stream_0'].keys())

for i in range (0, len(keys_1)):
    print(" {} - {}  - {}".format(keys_1[i], keys_2[i], keys_3[i]))
# Out:
#  InfoSegment - InfoSegment  - InfoSegment
#  SegmentData_0 - SegmentData_0  - SegmentData_0
#  SegmentData_1 - SegmentData_1  - SegmentData_1
#  SegmentData_10 - SegmentData_10  - SegmentData_10
#  SegmentData_100 - SegmentData_100  - SegmentData_100
#  SegmentData_101 - SegmentData_101  - SegmentData_101
#  SegmentData_102 - SegmentData_102  - SegmentData_102
#  SegmentData_103 - SegmentData_103  - SegmentData_103
#  SegmentData_104 - SegmentData_104  - SegmentData_104
#  SegmentData_105 - SegmentData_105  - SegmentData_105
#  SegmentData_106 - SegmentData_106  - SegmentData_106
#  SegmentData_107 - SegmentData_107  - SegmentData_107
#  SegmentData_108 - SegmentData_108  - SegmentData_108
#  SegmentData_109 - SegmentData_109  - SegmentData_109
#  SegmentData_110 - SegmentData_11  - SegmentData_11
#  SegmentData_111 - SegmentData_110  - SegmentData_110
#  SegmentData_112 - SegmentData_111  - SegmentData_111
#  SegmentData_113 - SegmentData_112  - SegmentData_112
# ...

# %%
# No se tiene la misma cantida de segmentos
